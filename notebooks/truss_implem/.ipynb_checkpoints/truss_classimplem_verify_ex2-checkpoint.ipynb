# %% [markdown]
# Verifying the class Implementation using Example

# %%
import math
import numpy as np
import copy
from IPython.display import Image

# %%
Image("eg1p1.png")

# %%
Image("eg1p2.png")

# %%
Image("eg1p3.png")

# %%
Image("eg1p4.png")

# %%
Image("eg1p5.png")

# %%
#import classes for nodes and elements
from node import node
from ele import ele

# %%
#define nodes along with boundary conditions
node1 = node(1,0,0,0,0,np.nan,np.nan)
node2 = node(2,2,0,np.nan,0,np.nan,20000)
node3 = node(3,2,2,np.nan,np.nan,25000,np.nan)
node4 = node(4,0,0,0,0,np.nan,np.nan)

# %%
node1.print()
node2.print()
node3.print()
node4.print()
# Out:
# num =  1
#  pos_x = 0
#  pos_y =  0
#  dis_x =  0
#  dis_y =  0
#  f_x =  nan
#  f_y =  nan
# num =  2
#  pos_x = 2
#  pos_y =  0
#  dis_x =  nan
#  dis_y =  0
#  f_x =  nan
#  f_y =  20000
# num =  3
#  pos_x = 2
#  pos_y =  2
#  dis_x =  nan
#  dis_y =  nan
#  f_x =  25000
#  f_y =  nan
# num =  4
#  pos_x = 0
#  pos_y =  0
#  dis_x =  0
#  dis_y =  0
#  f_x =  nan
#  f_y =  nan
# 0

# %%
#define elements

ele1 = ele(1, 40, 1, 29.5*10**6, 0 , 1 , 2)
ele2 = ele(2, 30, 1, 29.5*10**6, math.pi / 2 , 2 , 3)
ele3 = ele(3, 50, 1, 29.5*10**6, 0.6435011 , 1 , 3)
ele4 = ele(4, 40, 1, 29.5*10**6, 0 , 4 , 3 )

# %%
ele1.print()
ele2.print()
ele3.print()
ele4.print()
# Out:
# num =  1
#  length= 40
#  area =  1
#  youngs modulus =  29500000.0
#  theta =  0
#  node_a =  1
#  node_b =  2
# num =  2
#  length= 30
#  area =  1
#  youngs modulus =  29500000.0
#  theta =  1.5707963267948966
#  node_a =  2
#  node_b =  3
# num =  3
#  length= 50
#  area =  1
#  youngs modulus =  29500000.0
#  theta =  0.6435011
#  node_a =  1
#  node_b =  3
# num =  4
#  length= 40
#  area =  1
#  youngs modulus =  29500000.0
#  theta =  0
#  node_a =  4
#  node_b =  3
# 0

# %%
#generating stiffness matrix for all elements

print(ele1.stiff())
print(ele2.stiff())
print(ele3.stiff())
print(ele4.stiff())
# Out:
# [[ 737500.       0. -737500.      -0.]
#  [      0.       0.      -0.      -0.]
#  [-737500.      -0.  737500.       0.]
#  [     -0.      -0.       0.       0.]]
# [[ 3.68690947e-27  6.02118010e-11 -3.68690947e-27 -6.02118010e-11]
#  [ 6.02118010e-11  9.83333333e+05 -6.02118010e-11 -9.83333333e+05]
#  [-3.68690947e-27 -6.02118010e-11  3.68690947e-27  6.02118010e-11]
#  [-6.02118010e-11 -9.83333333e+05  6.02118010e-11  9.83333333e+05]]
# [[ 377600.00498052  283199.99854735 -377600.00498052 -283199.99854735]
#  [ 283199.99854735  212399.99501948 -283199.99854735 -212399.99501948]
#  [-377600.00498052 -283199.99854735  377600.00498052  283199.99854735]
#  [-283199.99854735 -212399.99501948  283199.99854735  212399.99501948]]
# [[ 737500.       0. -737500.      -0.]
#  [      0.       0.      -0.      -0.]
#  [-737500.      -0.  737500.       0.]
#  [     -0.      -0.       0.       0.]]

# %%
#list of nodes and elements
nodes = [node1 , node2 , node3, node4]
eles = [ele1 , ele2 ,ele3, ele4]

# %%
#generate global stiffness matrix 

def globalstiff(eles , num_nodes):
    #dimension of global matrix
    dim = 2 * num_nodes
    #generate and store the element-wise stiffness matrices
    SMs = [e.stiff() for e in eles]
    
    GK = np.zeros((dim,dim))
    for i in range(1,dim+1):
        for j in range(1,dim + 1):
            for k in range(0 , num_nodes):
                e = eles[k]
                if e.node_a == math.ceil(i/2):
                    if e.node_a == math.ceil(j/2):
                        GK[i-1][j-1] += SMs[k][(i+1)%2][(j+1)%2]
                    if e.node_b == math.ceil(j/2):
                        GK[i-1][j-1] += SMs[k][i%2][2+(j+1)%2]
                if e.node_b == math.ceil(i/2):
                    if e.node_a == math.ceil(j/2):
                        GK[i-1][j-1] += SMs[k][2+(i+1)%2][j%2]
                    if e.node_b == math.ceil(j/2):
                        GK[i-1][j-1] += SMs[k][2+(i+1)%2][2+(j+1)%2]
    return GK

# %%
GK = globalstiff(eles , 4)
GK
# Out:
# array([[ 1.11510000e+06,  2.83199999e+05,  0.00000000e+00,
#          0.00000000e+00, -2.83199999e+05, -2.12399995e+05,
#          0.00000000e+00,  0.00000000e+00],
#        [ 2.83199999e+05,  2.12399995e+05, -7.37500000e+05,
#          0.00000000e+00, -3.77600005e+05, -2.83199999e+05,
#          0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -7.37500000e+05,  7.37500000e+05,
#          6.02118010e-11, -6.02118010e-11, -9.83333333e+05,
#          0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  6.02118010e-11,
#          9.83333333e+05, -3.68690947e-27, -6.02118010e-11,
#          0.00000000e+00,  0.00000000e+00],
#        [-2.83199999e+05, -3.77600005e+05, -6.02118010e-11,
#         -3.68690947e-27,  1.11510000e+06,  2.83199999e+05,
#          0.00000000e+00, -7.37500000e+05],
#        [-2.12399995e+05, -2.83199999e+05, -9.83333333e+05,
#         -6.02118010e-11,  2.83199999e+05,  1.19573333e+06,
#          0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          7.37500000e+05,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -7.37500000e+05,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00]])

# %%
#create vector for node_dis and external_forces

dis_list = []
for n in nodes:
    dis_list.append(n.dis_x)
    dis_list.append(n.dis_y)
    
dis = np.array(dis_list)
print(dis)

f_list = []
for n in nodes:
    f_list.append(n.f_x)
    f_list.append(n.f_y)
    
f = np.array(f_list)
print(f)
# Out:
# [ 0.  0. nan  0. nan nan  0.  0.]
# [   nan    nan    nan 20000. 25000.    nan    nan    nan]

# %%
#check for undetermined values in force and create linear eqns

GK_dis =  copy.deepcopy(GK)
f_dis =  copy.deepcopy(f)

del_row = []
index_list = list(range(0,2*len(nodes)))
for i in range(0,2*len(nodes)):
    if dis_list[i] == 0:
        del_row.append(i)
        index_list.remove(i)
        
print(del_row)
print(index_list)
        
GK_dis = np.delete(GK_dis,del_row,0)
GK_dis = np.delete(GK_dis,del_row,1)
f_dis = np.delete(f_dis,del_row,0)
    
print(GK_dis)
print(f_dis)
# Out:
# [0, 1, 3, 6, 7]
# [2, 4, 5]
# [[ 7.37500000e+05 -6.02118010e-11 -9.83333333e+05]
#  [-6.02118010e-11  1.11510000e+06  2.83199999e+05]
#  [-9.83333333e+05  2.83199999e+05  1.19573333e+06]]
# [   nan 25000.    nan]

# %%
ans_dis = np.linalg.solve(GK_dis , f_dis)
ans_dis
# Out:
# array([nan, nan, nan])

# %%
for i in range(0 , len(ans_dis)):
    dis[index_list[i]] = ans_dis[i]
dis
# Out:
# array([ 0.,  0., nan,  0., nan, nan,  0.,  0.])

# %%
ans_force = np.dot(GK,dis)
ans_force
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan])
